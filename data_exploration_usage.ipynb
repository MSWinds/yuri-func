# %%
from utils.exploration import *
import pandas as pd
import numpy as np

# %%
# Set a random seed for reproducibility
np.random.seed(666)

# Generate sample data
data = {
    'Category_Small': np.random.choice(['A', 'B', 'C'], size=100),
    'Category_Large': np.random.choice(['L1', 'L2', 'L3', 'L4', 'L5', 'L6', 'L7', 'L8', 'L9', 'L10'], size=100),
    'Continuous_Normal': np.random.normal(loc=50, scale=15, size=100),
    'Continuous_Uniform': np.random.uniform(low=10, high=100, size=100),
    'Integer_Values': np.random.randint(1, 20, size=100),
    'Binary_Values': np.random.choice([0, 1], size=100)
}

# Create DataFrame
df = pd.DataFrame(data)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Category_Small      100 non-null    object
#  1   Category_Large      100 non-null    object
#  2   Continuous_Normal   100 non-null    float64
#  3   Continuous_Uniform  100 non-null    float64
#  4   Integer_Values      100 non-null    int32
#  5   Binary_Values       100 non-null    int32
# dtypes: float64(2), int32(2), object(2)
# memory usage: 4.0+ KB

# %%
data_exploration(df, 'Category_Small')
# Out:
# Counts and percentages of unique values in Category_Small:
#                 Count  Percentage
# Category_Small
# A                  36        36.0
# C                  34        34.0
# B                  30        30.0

# %%
data_exploration(df, 'Category_Large')
# Out:
# Counts and percentages of unique values in Category_Large:
#                 Count  Percentage
# Category_Large
# L10                16        16.0
# L9                 14        14.0
# L3                 12        12.0
# L5                 11        11.0
# L2                 10        10.0
# L1                  9         9.0
# L7                  8         8.0
# L6                  8         8.0
# L4                  6         6.0
# L8                  6         6.0

# %%
data_exploration(df, 'Continuous_Normal')
# Out:
# Mean of Continuous_Normal: 53.38
# Median of Continuous_Normal: 54.22
# Standard deviation of Continuous_Normal: 13.85
# Mode of Continuous_Normal: 22.50147650835604
# Number of outliers in Continuous_Normal: 0
# Number of extreme outliers in Continuous_Normal: 0

# %%
data_exploration(df, 'Continuous_Uniform')
# Out:
# Mean of Continuous_Uniform: 53.60
# Median of Continuous_Uniform: 48.04
# Standard deviation of Continuous_Uniform: 25.32
# Mode of Continuous_Uniform: 11.684879950592673
# Number of outliers in Continuous_Uniform: 0
# Number of extreme outliers in Continuous_Uniform: 0

# %%
data_exploration(df, 'Integer_Values')
# Out:
# Mean of Integer_Values: 9.38
# Median of Integer_Values: 9.00
# Standard deviation of Integer_Values: 5.41
# Mode of Integer_Values: 5
# Number of outliers in Integer_Values: 0
# Number of extreme outliers in Integer_Values: 0

# %%
data_exploration(df, 'Category_Small', 'Binary_Values')
# Out:
# Counts and percentages of unique values in Category_Small:
#                 Count  Percentage
# Category_Small
# A                  36        36.0
# C                  34        34.0
# B                  30        30.0

# %%
data_exploration(df, 'Binary_Values')
# Out:
# Counts and percentages of unique values in Binary_Values:
#                Count  Percentage
# Binary_Values
# 1                 51        51.0
# 0                 49        49.0
